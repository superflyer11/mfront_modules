# %%
import os
import sys
sys.path.append("/mofem_install/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-9.4.0/tfel-4.0.0-jjcwdu6cbil5dzqzjhjekn3jdzo3e6gc/lib/python3.11/site-packages")
import numpy as np
import mtest

m = mtest.MTest()
# mtest.setVerboseMode(mtest.VerboseLevel.VERBOSE_QUIET)
m.setMaximumNumberOfSubSteps(20)
m.setModellingHypothesis("Tridimensional")

model = "DruckerPragerSimple"


# Set  material model implementation and path
lib_path = "/mofem_install/jupyter/thomas/mfront_interface/src/libBehaviour.so"


b = mtest.Behaviour('generic', lib_path, model,'Tridimensional')
m.setBehaviour("generic", lib_path, model)
# in mfront gallery:
# tan(beta) * p + q - R_DP_0 = 0
#R_DP_0 is named d in gallery example

# in my own implementation
# - M_JP * p' + J - M_JP * c' / tan(phi) = 0
# J = q / sqrt(3)
# q = sqrt(3J2)

E = 150
nu = 0.3
# phi is the internal friction angle
phi = np.radians(35)
c = 30

# fitting at triaxial compression: lode angle = -30
# M_JP = 2 * np.sqrt(3) * np.sin(phi) / (3 - np.sin(phi))
# d = M_JP * c / np.tan(phi)

# Loading programme
tMax = 1.0  # s , total time
nTime = 200
ltime = np.linspace(0.0, tMax, nTime)
# Environment parameters
m.setExternalStateVariable("Temperature", 293.15)
# Material parameters
m.setMaterialProperty("YoungModulus", E)
m.setMaterialProperty("PoissonRatio", nu)
m.setMaterialProperty("phi", phi)
m.setMaterialProperty("c", c)

controls = ["stress", "strain"]
control = controls[0]
if control == "stress":
    p_con_0 =  0 # confining pressure
    p_con_1 =  00 # confining pressure
    p_axi_0 = 0
    p_axi_1 = 45
    m.setImposedStress("SXX", {0: p_con_0, 0.02: p_con_0, 1.0: p_con_1})
    m.setImposedStress("SYY", {0: p_con_0, 0.02: p_con_0, 1.0: p_con_1})
    m.setImposedStress("SZZ", {0: p_axi_0, 0.02: p_axi_0, 1.0: p_axi_1})
if control == "strain":
    # Set imposed strains for axial and confining directions
    m.setImposedStrain("EXX", {0: 0, 1.0: 0.00001})
    m.setImposedStrain("EYY", {0: 0, 1.0: 0.00001})
    m.setImposedStrain("EZZ", {0: 0, 1.0: 2.7})


s = mtest.MTestCurrentState()
wk = mtest.MTestWorkSpace()
m.completeInitialisation()
m.initializeCurrentState(s)
m.initializeWorkSpace(wk)


# run sim
for i in range(nTime - 1):
    # print(f"===========Loop {i}===========")
    m.execute(s, wk, ltime[i], ltime[i + 1])
# Out:
# ** no prediction
# resolution from 0 to 0.00502513
# iteration 1 : 0 0 (0 0 0 0 0 0)
# iteration 2 : 0 0 (0 0 0 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.00502513 to 0.0100503
# iteration 1 : 0 0 (0 0 0 0 0 0)
# iteration 2 : 0 0 (0 0 0 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0100503 to 0.0150754
# iteration 1 : 0 0 (0 0 0 0 0 0)
# iteration 2 : 0 0 (0 0 0 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0150754 to 0.0201005
# iteration 1 : 3.07661e-05 0.00461491 (-9.22982e-06 -9.22982e-06 3.07661e-05 0 0 0)
# iteration 2 : 4.92417e-18 1.00961e-15 (-9.22982e-06 -9.22982e-06 3.07661e-05 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0201005 to 0.0251256
# iteration 1 : 0.0015383 0.230746 (-0.000470721 -0.000470721 0.00156907 0 0 0)
# iteration 2 : 9.13578e-15 1.80336e-12 (-0.000470721 -0.000470721 0.00156907 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0251256 to 0.0301508
# iteration 1 : 0.0015383 0.230746 (-0.000932212 -0.000932212 0.00310737 0 0 0)
# iteration 2 : 9.13625e-15 1.80345e-12 (-0.000932212 -0.000932212 0.00310737 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0301508 to 0.0351759
# iteration 1 : 0.0015383 0.230746 (-0.0013937 -0.0013937 0.00464568 0 0 0)
# iteration 2 : 9.13556e-15 1.80334e-12 (-0.0013937 -0.0013937 0.00464568 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0351759 to 0.040201
# iteration 1 : 0.0015383 0.230746 (-0.00185519 -0.00185519 0.00618398 0 0 0)
# iteration 2 : 9.13613e-15 1.80345e-12 (-0.00185519 -0.00185519 0.00618398 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.040201 to 0.0452261
# iteration 1 : 0.0015383 0.230746 (-0.00231669 -0.00231669 0.00772228 0 0 0)
# iteration 2 : 9.13635e-15 1.80345e-12 (-0.00231669 -0.00231669 0.00772228 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0452261 to 0.0502513
# iteration 1 : 0.0015383 0.230746 (-0.00277818 -0.00277818 0.00926059 0 0 0)
# iteration 2 : 9.13382e-15 1.803e-12 (-0.00277818 -0.00277818 0.00926059 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0502513 to 0.0552764
# iteration 1 : 0.0015383 0.230746 (-0.00323967 -0.00323967 0.0107989 0 0 0)
# iteration 2 : 9.1352e-15 1.80322e-12 (-0.00323967 -0.00323967 0.0107989 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0552764 to 0.0603015
# iteration 1 : 0.0015383 0.230746 (-0.00370116 -0.00370116 0.0123372 0 0 0)
# iteration 2 : 9.13491e-15 1.80322e-12 (-0.00370116 -0.00370116 0.0123372 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0603015 to 0.0653266
# iteration 1 : 0.0015383 0.230746 (-0.00416265 -0.00416265 0.0138755 0 0 0)
# iteration 2 : 9.13569e-15 1.80345e-12 (-0.00416265 -0.00416265 0.0138755 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0653266 to 0.0703518
# iteration 1 : 0.0015383 0.230746 (-0.00462414 -0.00462414 0.0154138 0 0 0)
# iteration 2 : 9.13426e-15 1.803e-12 (-0.00462414 -0.00462414 0.0154138 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0703518 to 0.0753769
# iteration 1 : 0.0015383 0.230746 (-0.00508563 -0.00508563 0.0169521 0 0 0)
# iteration 2 : 9.13489e-15 1.803e-12 (-0.00508563 -0.00508563 0.0169521 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0753769 to 0.080402
# iteration 1 : 0.0015383 0.230746 (-0.00554712 -0.00554712 0.0184904 0 0 0)
# iteration 2 : 9.13591e-15 1.80345e-12 (-0.00554712 -0.00554712 0.0184904 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.080402 to 0.0854271
# iteration 1 : 0.0015383 0.230746 (-0.00600861 -0.00600861 0.0200287 0 0 0)
# iteration 2 : 9.13363e-15 1.803e-12 (-0.00600861 -0.00600861 0.0200287 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0854271 to 0.0904523
# iteration 1 : 0.0015383 0.230746 (-0.00647011 -0.00647011 0.021567 0 0 0)
# iteration 2 : 9.13511e-15 1.803e-12 (-0.00647011 -0.00647011 0.021567 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0904523 to 0.0954774
# iteration 1 : 0.0015383 0.230746 (-0.0069316 -0.0069316 0.0231053 0 0 0)
# iteration 2 : 9.13361e-15 1.803e-12 (-0.0069316 -0.0069316 0.0231053 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.0954774 to 0.100503
# iteration 1 : 0.0015383 0.230746 (-0.00739309 -0.00739309 0.0246436 0 0 0)
# iteration 2 : 9.13381e-15 1.803e-12 (-0.00739309 -0.00739309 0.0246436 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.100503 to 0.105528
# iteration 1 : 0.0015383 0.230746 (-0.00785458 -0.00785458 0.0261819 0 0 0)
# iteration 2 : 9.13364e-15 1.803e-12 (-0.00785458 -0.00785458 0.0261819 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.105528 to 0.110553
# iteration 1 : 0.0015383 0.230746 (-0.00831607 -0.00831607 0.0277202 0 0 0)
# iteration 2 : 9.13383e-15 1.803e-12 (-0.00831607 -0.00831607 0.0277202 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.110553 to 0.115578
# iteration 1 : 0.0015383 0.230746 (-0.00877756 -0.00877756 0.0292585 0 0 0)
# iteration 2 : 9.13403e-15 1.803e-12 (-0.00877756 -0.00877756 0.0292585 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.115578 to 0.120603
# iteration 1 : 0.0015383 0.230746 (-0.00923905 -0.00923905 0.0307968 0 0 0)
# iteration 2 : 9.13466e-15 1.803e-12 (-0.00923905 -0.00923905 0.0307968 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.120603 to 0.125628
# iteration 1 : 0.0015383 0.230746 (-0.00970054 -0.00970054 0.0323351 0 0 0)
# iteration 2 : 9.13539e-15 1.803e-12 (-0.00970054 -0.00970054 0.0323351 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.125628 to 0.130653
# iteration 1 : 0.0015383 0.230746 (-0.010162 -0.010162 0.0338734 0 0 0)
# iteration 2 : 9.13839e-15 1.80389e-12 (-0.010162 -0.010162 0.0338734 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.130653 to 0.135678
# iteration 1 : 0.0015383 0.230746 (-0.0106235 -0.0106235 0.0354118 0 0 0)
# iteration 2 : 9.14317e-15 1.80478e-12 (-0.0106235 -0.0106235 0.0354118 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.135678 to 0.140704
# iteration 1 : 0.0015383 0.230746 (-0.011085 -0.011085 0.0369501 0 0 0)
# iteration 2 : 9.13383e-15 1.803e-12 (-0.011085 -0.011085 0.0369501 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.140704 to 0.145729
# iteration 1 : 0.0015383 0.230746 (-0.0115465 -0.0115465 0.0384884 0 0 0)
# iteration 2 : 9.13852e-15 1.80389e-12 (-0.0115465 -0.0115465 0.0384884 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.145729 to 0.150754
# iteration 1 : 0.0015383 0.230746 (-0.012008 -0.012008 0.0400267 0 0 0)
# iteration 2 : 9.13996e-15 1.80389e-12 (-0.012008 -0.012008 0.0400267 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.150754 to 0.155779
# iteration 1 : 0.0015383 0.230746 (-0.0124695 -0.0124695 0.041565 0 0 0)
# iteration 2 : 9.13396e-15 1.803e-12 (-0.0124695 -0.0124695 0.041565 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.155779 to 0.160804
# iteration 1 : 0.0015383 0.230746 (-0.012931 -0.012931 0.0431033 0 0 0)
# iteration 2 : 9.13874e-15 1.80389e-12 (-0.012931 -0.012931 0.0431033 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.160804 to 0.165829
# iteration 1 : 0.0015383 0.230746 (-0.0133925 -0.0133925 0.0446416 0 0 0)
# iteration 2 : 9.13858e-15 1.80389e-12 (-0.0133925 -0.0133925 0.0446416 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.165829 to 0.170854
# iteration 1 : 0.0015383 0.230746 (-0.013854 -0.013854 0.0461799 0 0 0)
# iteration 2 : 9.13418e-15 1.803e-12 (-0.013854 -0.013854 0.0461799 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.170854 to 0.175879
# iteration 1 : 0.0015383 0.230746 (-0.0143155 -0.0143155 0.0477182 0 0 0)
# iteration 2 : 9.13887e-15 1.80389e-12 (-0.0143155 -0.0143155 0.0477182 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.175879 to 0.180905
# iteration 1 : 0.0015383 0.230746 (-0.0147769 -0.0147769 0.0492565 0 0 0)
# iteration 2 : 9.14463e-15 1.80478e-12 (-0.0147769 -0.0147769 0.0492565 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.180905 to 0.18593
# iteration 1 : 0.0015383 0.230746 (-0.0152384 -0.0152384 0.0507948 0 0 0)
# iteration 2 : 9.13854e-15 1.80389e-12 (-0.0152384 -0.0152384 0.0507948 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.18593 to 0.190955
# iteration 1 : 0.0015383 0.230746 (-0.0156999 -0.0156999 0.0523331 0 0 0)
# iteration 2 : 9.13749e-15 1.80389e-12 (-0.0156999 -0.0156999 0.0523331 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.190955 to 0.19598
# iteration 1 : 0.0015383 0.230746 (-0.0161614 -0.0161614 0.0538714 0 0 0)
# iteration 2 : 9.14316e-15 1.80478e-12 (-0.0161614 -0.0161614 0.0538714 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.19598 to 0.201005
# iteration 1 : 0.0015383 0.230746 (-0.0166229 -0.0166229 0.0554097 0 0 0)
# iteration 2 : 9.14202e-15 1.80478e-12 (-0.0166229 -0.0166229 0.0554097 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.201005 to 0.20603
# iteration 1 : 0.0015383 0.230746 (-0.0170844 -0.0170844 0.056948 0 0 0)
# iteration 2 : 9.13437e-15 1.803e-12 (-0.0170844 -0.0170844 0.056948 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.20603 to 0.211055
# iteration 1 : 0.0015383 0.230746 (-0.0175459 -0.0175459 0.0584863 0 0 0)
# iteration 2 : 9.13251e-15 1.803e-12 (-0.0175459 -0.0175459 0.0584863 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.211055 to 0.21608
# iteration 1 : 0.0015383 0.230746 (-0.0180074 -0.0180074 0.0600246 0 0 0)
# iteration 2 : 9.14233e-15 1.80478e-12 (-0.0180074 -0.0180074 0.0600246 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.21608 to 0.221106
# iteration 1 : 0.0015383 0.230746 (-0.0184689 -0.0184689 0.0615629 0 0 0)
# iteration 2 : 9.14545e-15 1.80478e-12 (-0.0184689 -0.0184689 0.0615629 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.221106 to 0.226131
# iteration 1 : 0.0015383 0.230746 (-0.0189304 -0.0189304 0.0631012 0 0 0)
# iteration 2 : 9.13513e-15 1.803e-12 (-0.0189304 -0.0189304 0.0631012 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.226131 to 0.231156
# iteration 1 : 0.0015383 0.230746 (-0.0193919 -0.0193919 0.0646395 0 0 0)
# iteration 2 : 9.13328e-15 1.803e-12 (-0.0193919 -0.0193919 0.0646395 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.231156 to 0.236181
# iteration 1 : 0.0015383 0.230746 (-0.0198533 -0.0198533 0.0661778 0 0 0)
# iteration 2 : 9.1348e-15 1.803e-12 (-0.0198533 -0.0198533 0.0661778 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.236181 to 0.241206
# iteration 1 : 0.0015383 0.230746 (-0.0203148 -0.0203148 0.0677161 0 0 0)
# iteration 2 : 9.12449e-15 1.80123e-12 (-0.0203148 -0.0203148 0.0677161 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.241206 to 0.246231
# iteration 1 : 0.0015383 0.230746 (-0.0207763 -0.0207763 0.0692544 0 0 0)
# iteration 2 : 9.13768e-15 1.803e-12 (-0.0207763 -0.0207763 0.0692544 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.246231 to 0.251256
# iteration 1 : 0.0015383 0.230746 (-0.0212378 -0.0212378 0.0707927 0 0 0)
# iteration 2 : 9.13262e-15 1.803e-12 (-0.0212378 -0.0212378 0.0707927 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.251256 to 0.256281
# iteration 1 : 0.0015383 0.230746 (-0.0216993 -0.0216993 0.072331 0 0 0)
# iteration 2 : 9.13219e-15 1.803e-12 (-0.0216993 -0.0216993 0.072331 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.256281 to 0.261307
# iteration 1 : 0.0015383 0.230746 (-0.0221608 -0.0221608 0.0738693 0 0 0)
# iteration 2 : 9.14539e-15 1.80478e-12 (-0.0221608 -0.0221608 0.0738693 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.261307 to 0.266332
# iteration 1 : 0.0015383 0.230746 (-0.0226223 -0.0226223 0.0754077 0 0 0)
# iteration 2 : 9.12518e-15 1.80123e-12 (-0.0226223 -0.0226223 0.0754077 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.266332 to 0.271357
# iteration 1 : 0.0015383 0.230746 (-0.0230838 -0.0230838 0.076946 0 0 0)
# iteration 2 : 9.1267e-15 1.80123e-12 (-0.0230838 -0.0230838 0.076946 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.271357 to 0.276382
# iteration 1 : 0.0015383 0.230746 (-0.0235453 -0.0235453 0.0784843 0 0 0)
# iteration 2 : 9.13474e-15 1.803e-12 (-0.0235453 -0.0235453 0.0784843 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.276382 to 0.281407
# iteration 1 : 0.0015383 0.230746 (-0.0240068 -0.0240068 0.0800226 0 0 0)
# iteration 2 : 9.13288e-15 1.803e-12 (-0.0240068 -0.0240068 0.0800226 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.281407 to 0.286432
# iteration 1 : 0.0015383 0.230746 (-0.0244683 -0.0244683 0.0815609 0 0 0)
# iteration 2 : 9.1443e-15 1.80478e-12 (-0.0244683 -0.0244683 0.0815609 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.286432 to 0.291457
# iteration 1 : 0.0015383 0.230746 (-0.0249298 -0.0249298 0.0830992 0 0 0)
# iteration 2 : 9.12427e-15 1.80123e-12 (-0.0249298 -0.0249298 0.0830992 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.291457 to 0.296482
# iteration 1 : 0.0015383 0.230746 (-0.0253912 -0.0253912 0.0846375 0 0 0)
# iteration 2 : 9.13746e-15 1.803e-12 (-0.0253912 -0.0253912 0.0846375 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.296482 to 0.301508
# iteration 1 : 0.0015383 0.230746 (-0.0258527 -0.0258527 0.0861758 0 0 0)
# iteration 2 : 9.12198e-15 1.80123e-12 (-0.0258527 -0.0258527 0.0861758 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.301508 to 0.306533
# iteration 1 : 0.0015383 0.230746 (-0.0263142 -0.0263142 0.0877141 0 0 0)
# iteration 2 : 9.14702e-15 1.80478e-12 (-0.0263142 -0.0263142 0.0877141 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.306533 to 0.311558
# iteration 1 : 0.0015383 0.230746 (-0.0267757 -0.0267757 0.0892524 0 0 0)
# iteration 2 : 9.13332e-15 1.803e-12 (-0.0267757 -0.0267757 0.0892524 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.311558 to 0.316583
# iteration 1 : 0.0015383 0.230746 (-0.0272372 -0.0272372 0.0907907 0 0 0)
# iteration 2 : 9.13502e-15 1.803e-12 (-0.0272372 -0.0272372 0.0907907 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.316583 to 0.321608
# iteration 1 : 0.0015383 0.230746 (-0.0276987 -0.0276987 0.092329 0 0 0)
# iteration 2 : 9.1247e-15 1.80123e-12 (-0.0276987 -0.0276987 0.092329 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.321608 to 0.326633
# iteration 1 : 0.0015383 0.230746 (-0.0281602 -0.0281602 0.0938673 0 0 0)
# iteration 2 : 9.12605e-15 1.80123e-12 (-0.0281602 -0.0281602 0.0938673 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.326633 to 0.331658
# iteration 1 : 0.0015383 0.230746 (-0.0286217 -0.0286217 0.0954056 0 0 0)
# iteration 2 : 9.1242e-15 1.80123e-12 (-0.0286217 -0.0286217 0.0954056 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.331658 to 0.336683
# iteration 1 : 0.0015383 0.230746 (-0.0290832 -0.0290832 0.0969439 0 0 0)
# iteration 2 : 9.13561e-15 1.803e-12 (-0.0290832 -0.0290832 0.0969439 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.336683 to 0.341709
# iteration 1 : 0.0015383 0.230746 (-0.0295447 -0.0295447 0.0984822 0 0 0)
# iteration 2 : 9.13376e-15 1.803e-12 (-0.0295447 -0.0295447 0.0984822 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.341709 to 0.346734
# iteration 1 : 0.0015383 0.230746 (-0.0300062 -0.0300062 0.100021 0 0 0)
# iteration 2 : 9.13511e-15 1.803e-12 (-0.0300062 -0.0300062 0.100021 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.346734 to 0.351759
# iteration 1 : 0.0015383 0.230746 (-0.0304676 -0.0304676 0.101559 0 0 0)
# iteration 2 : 9.13663e-15 1.803e-12 (-0.0304676 -0.0304676 0.101559 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.351759 to 0.356784
# iteration 1 : 0.0015383 0.230746 (-0.0309291 -0.0309291 0.103097 0 0 0)
# iteration 2 : 9.13496e-15 1.803e-12 (-0.0309291 -0.0309291 0.103097 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.356784 to 0.361809
# iteration 1 : 0.0015383 0.230746 (-0.0313906 -0.0313906 0.104635 0 0 0)
# iteration 2 : 9.12641e-15 1.80123e-12 (-0.0313906 -0.0313906 0.104635 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.361809 to 0.366834
# iteration 1 : 0.0015383 0.230746 (-0.0318521 -0.0318521 0.106174 0 0 0)
# iteration 2 : 9.12278e-15 1.80123e-12 (-0.0318521 -0.0318521 0.106174 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.366834 to 0.371859
# iteration 1 : 0.0015383 0.230746 (-0.0323136 -0.0323136 0.107712 0 0 0)
# iteration 2 : 9.12431e-15 1.80123e-12 (-0.0323136 -0.0323136 0.107712 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.371859 to 0.376884
# iteration 1 : 0.0015383 0.230746 (-0.0327751 -0.0327751 0.10925 0 0 0)
# iteration 2 : 9.13886e-15 1.80478e-12 (-0.0327751 -0.0327751 0.10925 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.376884 to 0.38191
# iteration 1 : 0.0015383 0.230746 (-0.0332366 -0.0332366 0.110789 0 0 0)
# iteration 2 : 9.12203e-15 1.80123e-12 (-0.0332366 -0.0332366 0.110789 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.38191 to 0.386935
# iteration 1 : 0.0015383 0.230746 (-0.0336981 -0.0336981 0.112327 0 0 0)
# iteration 2 : 9.12355e-15 1.80123e-12 (-0.0336981 -0.0336981 0.112327 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.386935 to 0.39196
# iteration 1 : 0.0015383 0.230746 (-0.0341596 -0.0341596 0.113865 0 0 0)
# iteration 2 : 9.12473e-15 1.80123e-12 (-0.0341596 -0.0341596 0.113865 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.39196 to 0.396985
# iteration 1 : 0.0015383 0.230746 (-0.0346211 -0.0346211 0.115404 0 0 0)
# iteration 2 : 9.1382e-15 1.80478e-12 (-0.0346211 -0.0346211 0.115404 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.396985 to 0.40201
# iteration 1 : 0.0015383 0.230746 (-0.0350826 -0.0350826 0.116942 0 0 0)
# iteration 2 : 9.14293e-15 1.80478e-12 (-0.0350826 -0.0350826 0.116942 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.40201 to 0.407035
# iteration 1 : 0.0015383 0.230746 (-0.035544 -0.035544 0.11848 0 0 0)
# iteration 2 : 9.11756e-15 1.80123e-12 (-0.035544 -0.035544 0.11848 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.407035 to 0.41206
# iteration 1 : 0.0015383 0.230746 (-0.0360055 -0.0360055 0.120018 0 0 0)
# iteration 2 : 9.14598e-15 1.80478e-12 (-0.0360055 -0.0360055 0.120018 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.41206 to 0.417085
# iteration 1 : 0.0015383 0.230746 (-0.036467 -0.036467 0.121557 0 0 0)
# iteration 2 : 9.12382e-15 1.80123e-12 (-0.036467 -0.036467 0.121557 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.417085 to 0.422111
# iteration 1 : 0.0015383 0.230746 (-0.0369285 -0.0369285 0.123095 0 0 0)
# iteration 2 : 9.13907e-15 1.80478e-12 (-0.0369285 -0.0369285 0.123095 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.422111 to 0.427136
# iteration 1 : 0.0015383 0.230746 (-0.03739 -0.03739 0.124633 0 0 0)
# iteration 2 : 9.12011e-15 1.80123e-12 (-0.03739 -0.03739 0.124633 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.427136 to 0.432161
# iteration 1 : 0.0015383 0.230746 (-0.0378515 -0.0378515 0.126172 0 0 0)
# iteration 2 : 9.12163e-15 1.80123e-12 (-0.0378515 -0.0378515 0.126172 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.432161 to 0.437186
# iteration 1 : 0.0015383 0.230746 (-0.038313 -0.038313 0.12771 0 0 0)
# iteration 2 : 9.13974e-15 1.80478e-12 (-0.038313 -0.038313 0.12771 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.437186 to 0.442211
# iteration 1 : 0.0015383 0.230746 (-0.0387745 -0.0387745 0.129248 0 0 0)
# iteration 2 : 9.14446e-15 1.80478e-12 (-0.0387745 -0.0387745 0.129248 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.442211 to 0.447236
# iteration 1 : 0.0015383 0.230746 (-0.039236 -0.039236 0.130787 0 0 0)
# iteration 2 : 9.12265e-15 1.80123e-12 (-0.039236 -0.039236 0.130787 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.447236 to 0.452261
# iteration 1 : 0.0015383 0.230746 (-0.0396975 -0.0396975 0.132325 0 0 0)
# iteration 2 : 9.14076e-15 1.80478e-12 (-0.0396975 -0.0396975 0.132325 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.452261 to 0.457286
# iteration 1 : 0.0015383 0.230746 (-0.040159 -0.040159 0.133863 0 0 0)
# iteration 2 : 9.1257e-15 1.80123e-12 (-0.040159 -0.040159 0.133863 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.457286 to 0.462312
# iteration 1 : 0.0015383 0.230746 (-0.0406204 -0.0406204 0.135401 0 0 0)
# iteration 2 : 9.13705e-15 1.80478e-12 (-0.0406204 -0.0406204 0.135401 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.462312 to 0.467337
# iteration 1 : 0.0015383 0.230746 (-0.0410819 -0.0410819 0.13694 0 0 0)
# iteration 2 : 9.14178e-15 1.80478e-12 (-0.0410819 -0.0410819 0.13694 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.467337 to 0.472362
# iteration 1 : 0.0015383 0.230746 (-0.0415434 -0.0415434 0.138478 0 0 0)
# iteration 2 : 9.11641e-15 1.80123e-12 (-0.0415434 -0.0415434 0.138478 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.472362 to 0.477387
# iteration 1 : 0.0015383 0.230746 (-0.0420049 -0.0420049 0.140016 0 0 0)
# iteration 2 : 9.14482e-15 1.80478e-12 (-0.0420049 -0.0420049 0.140016 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.477387 to 0.482412
# iteration 1 : 0.0015383 0.230746 (-0.0424664 -0.0424664 0.141555 0 0 0)
# iteration 2 : 9.14315e-15 1.80478e-12 (-0.0424664 -0.0424664 0.141555 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.482412 to 0.487437
# iteration 1 : 0.0015383 0.230746 (-0.0429279 -0.0429279 0.143093 0 0 0)
# iteration 2 : 9.11778e-15 1.80123e-12 (-0.0429279 -0.0429279 0.143093 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.487437 to 0.492462
# iteration 1 : 0.0015383 0.230746 (-0.0433894 -0.0433894 0.144631 0 0 0)
# iteration 2 : 9.14584e-15 1.80478e-12 (-0.0433894 -0.0433894 0.144631 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.492462 to 0.497487
# iteration 1 : 0.0015383 0.230746 (-0.0438509 -0.0438509 0.14617 0 0 0)
# iteration 2 : 9.12048e-15 1.80123e-12 (-0.0438509 -0.0438509 0.14617 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.497487 to 0.502513
# iteration 1 : 0.0015383 0.230746 (-0.0443124 -0.0443124 0.147708 0 0 0)
# iteration 2 : 9.13858e-15 1.80478e-12 (-0.0443124 -0.0443124 0.147708 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.502513 to 0.507538
# iteration 1 : 0.0015383 0.230746 (-0.0447739 -0.0447739 0.149246 0 0 0)
# iteration 2 : 9.12353e-15 1.80123e-12 (-0.0447739 -0.0447739 0.149246 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.507538 to 0.512563
# iteration 1 : 0.0015383 0.230746 (-0.0452354 -0.0452354 0.150785 0 0 0)
# iteration 2 : 9.16497e-15 1.80833e-12 (-0.0452354 -0.0452354 0.150785 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.512563 to 0.517588
# iteration 1 : 0.0015383 0.230746 (-0.0456969 -0.0456969 0.152323 0 0 0)
# iteration 2 : 9.11627e-15 1.80123e-12 (-0.0456969 -0.0456969 0.152323 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.517588 to 0.522613
# iteration 1 : 0.0015383 0.230746 (-0.0461583 -0.0461583 0.153861 0 0 0)
# iteration 2 : 9.14433e-15 1.80478e-12 (-0.0461583 -0.0461583 0.153861 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.522613 to 0.527638
# iteration 1 : 0.0015383 0.230746 (-0.0466198 -0.0466198 0.155399 0 0 0)
# iteration 2 : 9.12287e-15 1.80123e-12 (-0.0466198 -0.0466198 0.155399 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.527638 to 0.532663
# iteration 1 : 0.0015383 0.230746 (-0.0470813 -0.0470813 0.156938 0 0 0)
# iteration 2 : 9.14097e-15 1.80478e-12 (-0.0470813 -0.0470813 0.156938 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.532663 to 0.537688
# iteration 1 : 0.0015383 0.230746 (-0.0475428 -0.0475428 0.158476 0 0 0)
# iteration 2 : 9.12202e-15 1.80123e-12 (-0.0475428 -0.0475428 0.158476 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.537688 to 0.542714
# iteration 1 : 0.0015383 0.230746 (-0.0480043 -0.0480043 0.160014 0 0 0)
# iteration 2 : 9.14367e-15 1.80478e-12 (-0.0480043 -0.0480043 0.160014 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.542714 to 0.547739
# iteration 1 : 0.0015383 0.230746 (-0.0484658 -0.0484658 0.161553 0 0 0)
# iteration 2 : 9.14164e-15 1.80478e-12 (-0.0484658 -0.0484658 0.161553 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.547739 to 0.552764
# iteration 1 : 0.0015383 0.230746 (-0.0489273 -0.0489273 0.163091 0 0 0)
# iteration 2 : 9.11628e-15 1.80123e-12 (-0.0489273 -0.0489273 0.163091 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.552764 to 0.557789
# iteration 1 : 0.0015383 0.230746 (-0.0493888 -0.0493888 0.164629 0 0 0)
# iteration 2 : 9.14504e-15 1.80478e-12 (-0.0493888 -0.0493888 0.164629 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.557789 to 0.562814
# iteration 1 : 0.0015383 0.230746 (-0.0498503 -0.0498503 0.166168 0 0 0)
# iteration 2 : 9.11933e-15 1.80123e-12 (-0.0498503 -0.0498503 0.166168 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.562814 to 0.567839
# iteration 1 : 0.0015383 0.230746 (-0.0503118 -0.0503118 0.167706 0 0 0)
# iteration 2 : 9.13743e-15 1.80478e-12 (-0.0503118 -0.0503118 0.167706 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.567839 to 0.572864
# iteration 1 : 0.0015383 0.230746 (-0.0507733 -0.0507733 0.169244 0 0 0)
# iteration 2 : 9.14216e-15 1.80478e-12 (-0.0507733 -0.0507733 0.169244 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.572864 to 0.577889
# iteration 1 : 0.0015383 0.230746 (-0.0512347 -0.0512347 0.170782 0 0 0)
# iteration 2 : 9.14048e-15 1.80478e-12 (-0.0512347 -0.0512347 0.170782 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.577889 to 0.582915
# iteration 1 : 0.0015383 0.230746 (-0.0516962 -0.0516962 0.172321 0 0 0)
# iteration 2 : 9.10209e-15 1.79767e-12 (-0.0516962 -0.0516962 0.172321 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.582915 to 0.58794
# iteration 1 : 0.0015383 0.230746 (-0.0521577 -0.0521577 0.173859 0 0 0)
# iteration 2 : 9.14353e-15 1.80478e-12 (-0.0521577 -0.0521577 0.173859 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.58794 to 0.592965
# iteration 1 : 0.0015383 0.230746 (-0.0526192 -0.0526192 0.175397 0 0 0)
# iteration 2 : 9.11817e-15 1.80123e-12 (-0.0526192 -0.0526192 0.175397 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.592965 to 0.59799
# iteration 1 : 0.0015383 0.230746 (-0.0530807 -0.0530807 0.176936 0 0 0)
# iteration 2 : 9.13947e-15 1.80478e-12 (-0.0530807 -0.0530807 0.176936 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.59799 to 0.603015
# iteration 1 : 0.0015383 0.230746 (-0.0535422 -0.0535422 0.178474 0 0 0)
# iteration 2 : 9.12086e-15 1.80123e-12 (-0.0535422 -0.0535422 0.178474 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.603015 to 0.60804
# iteration 1 : 0.0015383 0.230746 (-0.0540037 -0.0540037 0.180012 0 0 0)
# iteration 2 : 9.14287e-15 1.80478e-12 (-0.0540037 -0.0540037 0.180012 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.60804 to 0.613065
# iteration 1 : 0.0015383 0.230746 (-0.0544652 -0.0544652 0.181551 0 0 0)
# iteration 2 : 9.14084e-15 1.80478e-12 (-0.0544652 -0.0544652 0.181551 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.613065 to 0.61809
# iteration 1 : 0.0015383 0.230746 (-0.0549267 -0.0549267 0.183089 0 0 0)
# iteration 2 : 9.12223e-15 1.80123e-12 (-0.0549267 -0.0549267 0.183089 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.61809 to 0.623116
# iteration 1 : 0.0015383 0.230746 (-0.0553882 -0.0553882 0.184627 0 0 0)
# iteration 2 : 9.14354e-15 1.80478e-12 (-0.0553882 -0.0553882 0.184627 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.623116 to 0.628141
# iteration 1 : 0.0015383 0.230746 (-0.0558497 -0.0558497 0.186166 0 0 0)
# iteration 2 : 9.14186e-15 1.80478e-12 (-0.0558497 -0.0558497 0.186166 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.628141 to 0.633166
# iteration 1 : 0.0015383 0.230746 (-0.0563111 -0.0563111 0.187704 0 0 0)
# iteration 2 : 9.11685e-15 1.80123e-12 (-0.0563111 -0.0563111 0.187704 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.633166 to 0.638191
# iteration 1 : 0.0015383 0.230746 (-0.0567726 -0.0567726 0.189242 0 0 0)
# iteration 2 : 9.14491e-15 1.80478e-12 (-0.0567726 -0.0567726 0.189242 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.638191 to 0.643216
# iteration 1 : 0.0015383 0.230746 (-0.0572341 -0.0572341 0.19078 0 0 0)
# iteration 2 : 9.11955e-15 1.80123e-12 (-0.0572341 -0.0572341 0.19078 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.643216 to 0.648241
# iteration 1 : 0.0015383 0.230746 (-0.0576956 -0.0576956 0.192319 0 0 0)
# iteration 2 : 9.1373e-15 1.80478e-12 (-0.0576956 -0.0576956 0.192319 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.648241 to 0.653266
# iteration 1 : 0.0015383 0.230746 (-0.0581571 -0.0581571 0.193857 0 0 0)
# iteration 2 : 9.14238e-15 1.80478e-12 (-0.0581571 -0.0581571 0.193857 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.653266 to 0.658291
# iteration 1 : 0.0015383 0.230746 (-0.0586186 -0.0586186 0.195395 0 0 0)
# iteration 2 : 9.12092e-15 1.80123e-12 (-0.0586186 -0.0586186 0.195395 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.658291 to 0.663317
# iteration 1 : 0.0015383 0.230746 (-0.0590801 -0.0590801 0.196934 0 0 0)
# iteration 2 : 9.13867e-15 1.80478e-12 (-0.0590801 -0.0590801 0.196934 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.663317 to 0.668342
# iteration 1 : 0.0015383 0.230746 (-0.0595416 -0.0595416 0.198472 0 0 0)
# iteration 2 : 9.12006e-15 1.80123e-12 (-0.0595416 -0.0595416 0.198472 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.668342 to 0.673367
# iteration 1 : 0.0015383 0.230746 (-0.0600031 -0.0600031 0.20001 0 0 0)
# iteration 2 : 9.14137e-15 1.80478e-12 (-0.0600031 -0.0600031 0.20001 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.673367 to 0.678392
# iteration 1 : 0.0015383 0.230746 (-0.0604646 -0.0604646 0.201549 0 0 0)
# iteration 2 : 9.14129e-15 1.80478e-12 (-0.0604646 -0.0604646 0.201549 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.678392 to 0.683417
# iteration 1 : 0.0015383 0.230746 (-0.0609261 -0.0609261 0.203087 0 0 0)
# iteration 2 : 9.12108e-15 1.80123e-12 (-0.0609261 -0.0609261 0.203087 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.683417 to 0.688442
# iteration 1 : 0.0015383 0.230746 (-0.0613875 -0.0613875 0.204625 0 0 0)
# iteration 2 : 9.14274e-15 1.80478e-12 (-0.0613875 -0.0613875 0.204625 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.688442 to 0.693467
# iteration 1 : 0.0015383 0.230746 (-0.061849 -0.061849 0.206163 0 0 0)
# iteration 2 : 9.14071e-15 1.80478e-12 (-0.061849 -0.061849 0.206163 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.693467 to 0.698492
# iteration 1 : 0.0015383 0.230746 (-0.0623105 -0.0623105 0.207702 0 0 0)
# iteration 2 : 9.1221e-15 1.80123e-12 (-0.0623105 -0.0623105 0.207702 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.698492 to 0.703518
# iteration 1 : 0.0015383 0.230746 (-0.062772 -0.062772 0.20924 0 0 0)
# iteration 2 : 9.15016e-15 1.80478e-12 (-0.062772 -0.062772 0.20924 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.703518 to 0.708543
# iteration 1 : 0.0015383 0.230746 (-0.0632335 -0.0632335 0.210778 0 0 0)
# iteration 2 : 9.12195e-15 1.80123e-12 (-0.0632335 -0.0632335 0.210778 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.708543 to 0.713568
# iteration 1 : 0.0015383 0.230746 (-0.063695 -0.063695 0.212317 0 0 0)
# iteration 2 : 9.15343e-15 1.80833e-12 (-0.063695 -0.063695 0.212317 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.713568 to 0.718593
# iteration 1 : 0.0015383 0.230746 (-0.0641565 -0.0641565 0.213855 0 0 0)
# iteration 2 : 9.13482e-15 1.80478e-12 (-0.0641565 -0.0641565 0.213855 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.718593 to 0.723618
# iteration 1 : 0.0015383 0.230746 (-0.064618 -0.064618 0.215393 0 0 0)
# iteration 2 : 9.1392e-15 1.80478e-12 (-0.064618 -0.064618 0.215393 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.723618 to 0.728643
# iteration 1 : 0.0015383 0.230746 (-0.0650795 -0.0650795 0.216932 0 0 0)
# iteration 2 : 9.09691e-15 1.79767e-12 (-0.0650795 -0.0650795 0.216932 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.728643 to 0.733668
# iteration 1 : 0.0015383 0.230746 (-0.065541 -0.065541 0.21847 0 0 0)
# iteration 2 : 9.1529e-15 1.80478e-12 (-0.065541 -0.065541 0.21847 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.733668 to 0.738693
# iteration 1 : 0.0015383 0.230746 (-0.0660025 -0.0660025 0.220008 0 0 0)
# iteration 2 : 9.14732e-15 1.80478e-12 (-0.0660025 -0.0660025 0.220008 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.738693 to 0.743719
# iteration 1 : 0.0015383 0.230746 (-0.066464 -0.066464 0.221547 0 0 0)
# iteration 2 : 9.09152e-15 1.79767e-12 (-0.066464 -0.066464 0.221547 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.743719 to 0.748744
# iteration 1 : 0.0015383 0.230746 (-0.0669254 -0.0669254 0.223085 0 0 0)
# iteration 2 : 9.14327e-15 1.80478e-12 (-0.0669254 -0.0669254 0.223085 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.748744 to 0.753769
# iteration 1 : 0.0015383 0.230746 (-0.0673869 -0.0673869 0.224623 0 0 0)
# iteration 2 : 9.14834e-15 1.80478e-12 (-0.0673869 -0.0673869 0.224623 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.753769 to 0.758794
# iteration 1 : 0.0015383 0.230746 (-0.0678484 -0.0678484 0.226161 0 0 0)
# iteration 2 : 9.13566e-15 1.80478e-12 (-0.0678484 -0.0678484 0.226161 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.758794 to 0.763819
# iteration 1 : 0.0015383 0.230746 (-0.0683099 -0.0683099 0.2277 0 0 0)
# iteration 2 : 9.13788e-15 1.80478e-12 (-0.0683099 -0.0683099 0.2277 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.763819 to 0.768844
# iteration 1 : 0.0015383 0.230746 (-0.0687714 -0.0687714 0.229238 0 0 0)
# iteration 2 : 9.14296e-15 1.80478e-12 (-0.0687714 -0.0687714 0.229238 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.768844 to 0.773869
# iteration 1 : 0.0015383 0.230746 (-0.0692329 -0.0692329 0.230776 0 0 0)
# iteration 2 : 9.14733e-15 1.80478e-12 (-0.0692329 -0.0692329 0.230776 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.773869 to 0.778894
# iteration 1 : 0.0015383 0.230746 (-0.0696944 -0.0696944 0.232315 0 0 0)
# iteration 2 : 9.13535e-15 1.80478e-12 (-0.0696944 -0.0696944 0.232315 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.778894 to 0.78392
# iteration 1 : 0.0015383 0.230746 (-0.0701559 -0.0701559 0.233853 0 0 0)
# iteration 2 : 9.09661e-15 1.79767e-12 (-0.0701559 -0.0701559 0.233853 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.78392 to 0.788945
# iteration 1 : 0.0015383 0.230746 (-0.0706174 -0.0706174 0.235391 0 0 0)
# iteration 2 : 9.1448e-15 1.80478e-12 (-0.0706174 -0.0706174 0.235391 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.788945 to 0.79397
# iteration 1 : 0.0015383 0.230746 (-0.0710789 -0.0710789 0.23693 0 0 0)
# iteration 2 : 9.13282e-15 1.80478e-12 (-0.0710789 -0.0710789 0.23693 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.79397 to 0.798995
# iteration 1 : 0.0015383 0.230746 (-0.0715404 -0.0715404 0.238468 0 0 0)
# iteration 2 : 9.14144e-15 1.80478e-12 (-0.0715404 -0.0715404 0.238468 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.798995 to 0.80402
# iteration 1 : 0.0015383 0.230746 (-0.0720018 -0.0720018 0.240006 0 0 0)
# iteration 2 : 9.1027e-15 1.79767e-12 (-0.0720018 -0.0720018 0.240006 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.80402 to 0.809045
# iteration 1 : 0.0015383 0.230746 (-0.0724633 -0.0724633 0.241544 0 0 0)
# iteration 2 : 9.14379e-15 1.80478e-12 (-0.0724633 -0.0724633 0.241544 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.809045 to 0.81407
# iteration 1 : 0.0015383 0.230746 (-0.0729248 -0.0729248 0.243083 0 0 0)
# iteration 2 : 9.10575e-15 1.79767e-12 (-0.0729248 -0.0729248 0.243083 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.81407 to 0.819095
# iteration 1 : 0.0015383 0.230746 (-0.0733863 -0.0733863 0.244621 0 0 0)
# iteration 2 : 9.14754e-15 1.80478e-12 (-0.0733863 -0.0733863 0.244621 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.819095 to 0.824121
# iteration 1 : 0.0015383 0.230746 (-0.0738478 -0.0738478 0.246159 0 0 0)
# iteration 2 : 9.13485e-15 1.80478e-12 (-0.0738478 -0.0738478 0.246159 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.824121 to 0.829146
# iteration 1 : 0.0015383 0.230746 (-0.0743093 -0.0743093 0.247698 0 0 0)
# iteration 2 : 9.14348e-15 1.80478e-12 (-0.0743093 -0.0743093 0.247698 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.829146 to 0.834171
# iteration 1 : 0.0015383 0.230746 (-0.0747708 -0.0747708 0.249236 0 0 0)
# iteration 2 : 9.10474e-15 1.79767e-12 (-0.0747708 -0.0747708 0.249236 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.834171 to 0.839196
# iteration 1 : 0.0015383 0.230746 (-0.0752323 -0.0752323 0.250774 0 0 0)
# iteration 2 : 9.13943e-15 1.80478e-12 (-0.0752323 -0.0752323 0.250774 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.839196 to 0.844221
# iteration 1 : 0.0015383 0.230746 (-0.0756938 -0.0756938 0.252313 0 0 0)
# iteration 2 : 9.18122e-15 1.81188e-12 (-0.0756938 -0.0756938 0.252313 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.844221 to 0.849246
# iteration 1 : 0.0015383 0.230746 (-0.0761553 -0.0761553 0.253851 0 0 0)
# iteration 2 : 9.13607e-15 1.80478e-12 (-0.0761553 -0.0761553 0.253851 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.849246 to 0.854271
# iteration 1 : 0.0015383 0.230746 (-0.0766168 -0.0766168 0.255389 0 0 0)
# iteration 2 : 9.17716e-15 1.81188e-12 (-0.0766168 -0.0766168 0.255389 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.854271 to 0.859296
# iteration 1 : 0.0015383 0.230746 (-0.0770782 -0.0770782 0.256927 0 0 0)
# iteration 2 : 9.09815e-15 1.79767e-12 (-0.0770782 -0.0770782 0.256927 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.859296 to 0.864322
# iteration 1 : 0.0015383 0.230746 (-0.0775397 -0.0775397 0.258466 0 0 0)
# iteration 2 : 9.1738e-15 1.81188e-12 (-0.0775397 -0.0775397 0.258466 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.864322 to 0.869347
# iteration 1 : 0.0015383 0.230746 (-0.0780012 -0.0780012 0.260004 0 0 0)
# iteration 2 : 9.13436e-15 1.80478e-12 (-0.0780012 -0.0780012 0.260004 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.869347 to 0.874372
# iteration 1 : 0.0015383 0.230746 (-0.0784627 -0.0784627 0.261542 0 0 0)
# iteration 2 : 9.18326e-15 1.81188e-12 (-0.0784627 -0.0784627 0.261542 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.874372 to 0.879397
# iteration 1 : 0.0015383 0.230746 (-0.0789242 -0.0789242 0.263081 0 0 0)
# iteration 2 : 9.131e-15 1.80478e-12 (-0.0789242 -0.0789242 0.263081 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.879397 to 0.884422
# iteration 1 : 0.0015383 0.230746 (-0.0793857 -0.0793857 0.264619 0 0 0)
# iteration 2 : 9.14604e-15 1.80478e-12 (-0.0793857 -0.0793857 0.264619 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.884422 to 0.889447
# iteration 1 : 0.0015383 0.230746 (-0.0798472 -0.0798472 0.266157 0 0 0)
# iteration 2 : 9.17432e-15 1.81188e-12 (-0.0798472 -0.0798472 0.266157 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.889447 to 0.894472
# iteration 1 : 0.0015383 0.230746 (-0.0803087 -0.0803087 0.267696 0 0 0)
# iteration 2 : 9.14268e-15 1.80478e-12 (-0.0803087 -0.0803087 0.267696 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.894472 to 0.899497
# iteration 1 : 0.0015383 0.230746 (-0.0807702 -0.0807702 0.269234 0 0 0)
# iteration 2 : 9.1371e-15 1.80478e-12 (-0.0807702 -0.0807702 0.269234 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.899497 to 0.904523
# iteration 1 : 0.0015383 0.230746 (-0.0812317 -0.0812317 0.270772 0 0 0)
# iteration 2 : 9.17819e-15 1.81188e-12 (-0.0812317 -0.0812317 0.270772 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.904523 to 0.909548
# iteration 1 : 0.0015383 0.230746 (-0.0816932 -0.0816932 0.272311 0 0 0)
# iteration 2 : 9.14656e-15 1.80478e-12 (-0.0816932 -0.0816932 0.272311 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.909548 to 0.914573
# iteration 1 : 0.0015383 0.230746 (-0.0821547 -0.0821547 0.273849 0 0 0)
# iteration 2 : 9.13527e-15 1.80478e-12 (-0.0821547 -0.0821547 0.273849 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.914573 to 0.919598
# iteration 1 : 0.0015383 0.230746 (-0.0826161 -0.0826161 0.275387 0 0 0)
# iteration 2 : 1.34044e+13 0.0467577 (6.70221e+12 6.70221e+12 -1.34044e+13 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.914573 to 0.917085
# iteration 1 : 0.000769152 0.115373 (-0.0823854 -0.0823854 0.274618 0 0 0)
# iteration 2 : 3.80007e-15 7.88702e-13 (-0.0823854 -0.0823854 0.274618 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.917085 to 0.919598
# iteration 1 : 0.000769152 0.115373 (-0.0826161 -0.0826161 0.275387 0 0 0)
# iteration 2 : 7.65967e+11 0.0467577 (3.82983e+11 3.82983e+11 -7.65967e+11 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.917085 to 0.918342
# iteration 1 : 0.000384576 0.0576864 (-0.0825008 -0.0825008 0.275003 0 0 0)
# iteration 2 : 2.20574e-16 3.55271e-14 (-0.0825008 -0.0825008 0.275003 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.918342 to 0.919598
# iteration 1 : 0.000384576 0.0576864 (-0.0826161 -0.0826161 0.275387 0 0 0)
# iteration 2 : 1.09424e+12 0.0467577 (-5.47119e+11 -5.47119e+11 1.09424e+12 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918342 to 0.91897
# iteration 1 : 0.000192288 0.0288432 (-0.0825585 -0.0825585 0.275195 0 0 0)
# iteration 2 : 1.05716e+13 0.018438 (5.28578e+12 5.28578e+12 -1.05716e+13 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918342 to 0.918656
# iteration 1 : 9.6144e-05 0.0144216 (-0.0825296 -0.0825296 0.275099 0 0 0)
# iteration 2 : 9.43432e+10 0.00427818 (4.71716e+10 4.71716e+10 -9.43432e+10 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918342 to 0.918499
# iteration 1 : 4.8072e-05 0.0072108 (-0.0825152 -0.0825152 0.275051 0 0 0)
# iteration 2 : 1.18815e-17 2.54603e-15 (-0.0825152 -0.0825152 0.275051 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.918499 to 0.918656
# iteration 1 : 4.8072e-05 0.0072108 (-0.0825296 -0.0825296 0.275099 0 0 0)
# iteration 2 : 1.14089e+11 0.00427818 (5.70447e+10 5.70447e+10 -1.14089e+11 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918499 to 0.918577
# iteration 1 : 2.4036e-05 0.0036054 (-0.0825224 -0.0825224 0.275075 0 0 0)
# iteration 2 : 1.51165e+10 0.00073822 (7.55827e+09 7.55827e+09 -1.51165e+10 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918499 to 0.918538
# iteration 1 : 1.2018e-05 0.0018027 (-0.0825188 -0.0825188 0.275063 0 0 0)
# iteration 2 : 4.24803e-17 7.10543e-15 (-0.0825188 -0.0825188 0.275063 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.918538 to 0.918577
# iteration 1 : 1.2018e-05 0.0018027 (-0.0825224 -0.0825224 0.275075 0 0 0)
# iteration 2 : 2.41865e+10 0.00073822 (-1.20932e+10 -1.20932e+10 2.41865e+10 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918538 to 0.918558
# iteration 1 : 6.009e-06 0.00090135 (-0.0825206 -0.0825206 0.275069 0 0 0)
# iteration 2 : 3.75526e-17 7.10543e-15 (-0.0825206 -0.0825206 0.275069 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.918558 to 0.918577
# iteration 1 : 6.009e-06 0.00090135 (-0.0825224 -0.0825224 0.275075 0 0 0)
# iteration 2 : 9.40584e+10 0.00073822 (-4.70292e+10 -4.70292e+10 9.40584e+10 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918558 to 0.918567
# iteration 1 : 3.0045e-06 0.000450675 (-0.0825215 -0.0825215 0.275072 0 0 0)
# iteration 2 : 1.09391e+10 0.000295724 (5.46953e+09 5.46953e+09 -1.09391e+10 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918558 to 0.918563
# iteration 1 : 1.50225e-06 0.000225337 (-0.082521 -0.082521 0.27507 0 0 0)
# iteration 2 : 2.08301e+09 7.44768e-05 (-1.04151e+09 -1.04151e+09 2.08301e+09 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918558 to 0.91856
# iteration 1 : 7.51125e-07 0.000112669 (-0.0825208 -0.0825208 0.275069 0 0 0)
# iteration 2 : 6.82006e-18 1.46144e-15 (-0.0825208 -0.0825208 0.275069 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.91856 to 0.918563
# iteration 1 : 7.51125e-07 0.000112669 (-0.082521 -0.082521 0.27507 0 0 0)
# iteration 2 : 5.33772e+09 7.44768e-05 (-2.66886e+09 -2.66886e+09 5.33772e+09 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.91856 to 0.918561
# iteration 1 : 3.75562e-07 5.63344e-05 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 4.48503e+08 1.91649e-05 (-2.24252e+08 -2.24252e+08 4.48503e+08 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.91856 to 0.918561
# iteration 1 : 1.87781e-07 2.81672e-05 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 3.17111e-17 7.10543e-15 (-0.0825209 -0.0825209 0.27507 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.918561 to 0.918561
# iteration 1 : 1.87781e-07 2.81672e-05 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 4.39533e+09 1.91649e-05 (2.19767e+09 2.19767e+09 -4.39533e+09 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918561 to 0.918561
# iteration 1 : 9.38906e-08 1.40836e-05 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 1.3909e+08 5.33696e-06 (-6.95449e+07 -6.95449e+07 1.3909e+08 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918561 to 0.918561
# iteration 1 : 4.69453e-08 7.0418e-06 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 8.98212e-18 1.92474e-15 (-0.0825209 -0.0825209 0.27507 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.918561 to 0.918561
# iteration 1 : 4.69453e-08 7.0418e-06 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 1.61051e+08 5.33696e-06 (8.05257e+07 8.05257e+07 -1.61051e+08 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918561 to 0.918561
# iteration 1 : 2.34727e-08 3.5209e-06 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 3.59296e+08 1.87996e-06 (1.79648e+08 1.79648e+08 -3.59296e+08 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918561 to 0.918561
# iteration 1 : 1.17363e-08 1.76045e-06 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 5.78954e+07 1.51464e-07 (-2.89477e+07 -2.89477e+07 5.78954e+07 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918561 to 0.918561
# iteration 1 : 5.86816e-09 8.80224e-07 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 1.08453e-17 2.324e-15 (-0.0825209 -0.0825209 0.27507 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.918561 to 0.918561
# iteration 1 : 5.86816e-09 8.80224e-07 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 9.14137e+06 1.51464e-07 (-4.57069e+06 -4.57069e+06 9.14137e+06 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# Dividing time step by two
#
# resolution from 0.918561 to 0.918561
# iteration 1 : 2.93408e-09 4.40112e-07 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 3.77917e-17 7.10543e-15 (-0.0825209 -0.0825209 0.27507 0 0 0)
# convergence, after 2 iterations, order undefined
#
# resolution from 0.918561 to 0.918561
# iteration 1 : 2.93408e-09 4.40112e-07 (-0.0825209 -0.0825209 0.27507 0 0 0)
# iteration 2 : 3.47372e+07 1.51464e-07 (-1.73686e+07 -1.73686e+07 3.47372e+07 0 0 0)
# iteration 3 : 689231 1.51216e-07 (-1.7024e+07 -1.7024e+07 3.4048e+07 0 0 0)
#
# MTest::computeStiffnessMatrixAndResidual : behaviour intregration failed
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 79
#      76 # run sim
#      77 for i in range(nTime - 1):
#      78     # print(f"===========Loop {i}===========")
# ---> 79     m.execute(s, wk, ltime[i], ltime[i + 1])
#
# RuntimeError: GenericSolver::execute: maximum number of sub stepping reached

# %%
import gmsh
from pydantic import BaseModel
import os
import sys
sys.path.append('/mofem_install/jupyter/thomas/mfront_example_test/src')

import mesh_create as mshcrte
import custom_models as cm
import utils as ut
import plotting

os.chdir("/mofem_install/jupyter/thomas/mfront_example_test")
class Box(BaseModel):
    x: float = 0
    y: float = 0
    z: float = 0
    dx: float = 80
    dy: float = 80
    dz: float = 29.5

    def create(self):
        
        gmsh.initialize()
        gmsh.option.setNumber("General.Verbosity", 99)
        
        pt1 = gmsh.model.occ.addPoint(self.x, self.y, self.z)
        pt2 = gmsh.model.occ.addPoint(self.x + self.dx , self.y, self.z)
        pt3 = gmsh.model.occ.addPoint(self.x + self.dx , self.y + self.dy, self.z)
        cpt1 = gmsh.model.occ.addPoint(41,40,0)
        cpt2 = gmsh.model.occ.addPoint(40,39,0)
        cpt3 = gmsh.model.occ.addPoint(39,40,0)
        pt4 = gmsh.model.occ.addPoint(self.x, self.y + self.dy, self.z)

        l1 = gmsh.model.occ.addLine(pt1, pt2)
        l2 = gmsh.model.occ.addLine(pt2, pt3)
        l3 = gmsh.model.occ.addLine(pt3, cpt3)
        cA1 = gmsh.model.occ.addCircleArc(cpt1,cpt2,cpt3)
        l4 = gmsh.model.occ.addLine(cpt1, pt4)
        l5 = gmsh.model.occ.addLine(pt4, pt1)
        cl1 = gmsh.model.occ.addCurveLoop([l1,l2,l3, cA1, l4, l5])
        s1 = gmsh.model.occ.addPlaneSurface([cl1])
        # total_depth = 20
        volume = gmsh.model.occ.extrude([(2, s1)], 0, 0, 29.5, [2], recombine=True)
        print(volume)
        for i in volume:
            if i[0] == 3:
                dimTag = i[1]
                break
        test = mshcrte.get_surface_extremes(dimTag)
        print(test)
        volume2 = gmsh.model.occ.extrude([(2, test.max_z_surfaces[0])], 0, 0, 14.1, [2], recombine=True)
        for i in volume:
            if i[0] == 3:
                dimTag2 = i[1]
                break
            
        
        
        # pile_manager = cm.PileManager(x=0, y=0, z=29.5+14.1, dx=0, dy=0, dz=-20.5, R=1, r=0.975,
        #                         preferred_model= cm.PropertyTypeEnum.elastic,
        #                         props = {cm.PropertyTypeEnum.elastic: cm.LinearElasticProperties(youngs_modulus=200000*(10**6), poisson_ratio=0.3)},
        #                         )
        
        # outer_cylinder_tag, inner_cylinder_tag = pile_manager.addPile()
        
        # cut_soil_tags, _ = gmsh.model.occ.cut(
        #     [[3, tag] for tag in [dimTag, dimTag2]],
        #     [[3, outer_cylinder_tag]],
        #     -1,
        #     removeObject=True,
        #     removeTool=False,
        # )
        # cut_soil_boxes = [tag for _, tag in cut_soil_tags]

        # symmetry_cutter_tag = gmsh.model.occ.addBox(-200, 0, -200, 400, 400, 400)

        # # Cut the outer cylinder with the inner cylinder to form the pile
        # cut_pile_tags, _ = gmsh.model.occ.cut(
        #     [[3, outer_cylinder_tag]],
        #     [[3, inner_cylinder_tag]],
        #     -1,
        #     removeObject=True,
        #     removeTool=True,
        # )
        # pile_vols = [tag for dim, tag in cut_pile_tags]
        
        
        gmsh.model.occ.synchronize()
        for curve in [l1,l2,l3,l4]:
            gmsh.model.mesh.setTransfiniteCurve(curve,10)
            
        for surf in gmsh.model.getEntities(2):
            gmsh.model.mesh.setTransfiniteSurface(surf[1])
        
        for vol in gmsh.model.getEntities(3):
            gmsh.model.mesh.setTransfiniteVolume(vol[1])
        
        gmsh.option.setNumber('Mesh.RecombineAll', 1)
        gmsh.option.setNumber('Mesh.Recombine3DAll', 1)
        gmsh.option.setNumber('Mesh.RecombinationAlgorithm', 2)
        # gmsh.option.setNumber('Mesh.Recombine3DLevel', 0)
        gmsh.option.setNumber('Mesh.SaveAll', 1)
        # gmsh.option.setNumber('Mesh.SaveGroupsOfNodes', 1)
        # gmsh.option.setNumber('Mesh.SecondOrderIncomplete', 1)
        # gmsh.option.setNumber("Mesh.MeshSizeMax", 10)
        # gmsh.option.setNumber("Mesh.MeshSizeMax", 0.5)


        gmsh.model.mesh.generate(3)
        gmsh.model.mesh.recombine()
        gmsh.write("testing.med")
        gmsh.finalize()
    
    
Box().create()
